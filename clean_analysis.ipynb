# %% [markdown]
# # Questions
#
# ## Hypothesis Testing
#
# - Completion Rate: The proportion of users who reach the final ‘confirm’ step.
# - Time Spent on Each Step: The average duration users spend on each step.
# - Error Rates: If there’s a step where users go back to a previous step, it may indicate confusion or an error. You should consider moving from a later step to an earlier one as an error.
# - Based on the chosen KPIs, how does the new design’s performance compare to the old one?
# - You are required to carry out another analysis, ensuring that the observed increase in completion rate from the A/B test meets or exceeds this 5% threshold.
# - You might want to test whether the average age of clients engaging with the new process is the same as those engaging with the old process
# - You might want to test if the average client tenure (how long they’ve been with Vanguard) of those engaging with the new process is the same as those engaging with the old process
# - You might want to test if there are gender differences that affect engaging with the new or old process
#
# **Design Effectiveness**
#
# - Was the experiment well-structured?
# - Were clients randomly and equally divided between the old and new designs?
# - Were there any biases?
#
# **Duration Assessment**
# - Was the timeframe of the experiment (from 3/15/2017 to 6/20/2017) adequate to gather meaningful data and insights?
#
# **Additional Data Needs**
#
# - What other data, if available, could enhance the analysis?
# Bonus: Additional Tasks (Optional)
#
# We want to understand exactly what changes have been made between the original landing page and the test landing page. What specific design, layout, content, or CTA elements were modified? This will help us pinpoint which changes might influence user behaviour. Data and recordings from softwares such as Hotjar and GA4 (Google Analytics) could help us provide more detailed information about the customers and user behavior and compare it with the current landing page and test landing page.
# We also want to know more about the products being sold. What are they, what are their prices, and how are they presented on each version of the page? Understanding the business context is important too, in which field or market does the company operate? Who are the competitors?
#
# **With Hotjar we want to examine:**
# - Which buttons users are clicking, and which are being ignored.
# - Heatmaps showing user engagement and scroll behaviour on each landing page of the funnel.
# - Are users interacting with the forms or CTAs (e.g. “Buy now”, “Subscribe”)?
# - Session recordings to see how users are navigating and where friction might occur.
# - How far do users scroll on each version?
# - On-page surveys to understand what users are thinking ("What were you looking for?", "Was this useful?) - with Hotjar you have the possibility to create a pop-up banner.
#
# **With GA4, for deeper insights into funnel behaviour, we want to know the following:**
# - Website performance metrics like page load speed, error rates, or broken elements.
# - Data information about the devices and browsers of the visitors and customers. Is there for example a difference in behaviour - between desktop and mobile users?
# - Touch points and channels of where users are coming from? (Do different traffic sources behave differently on version A vs B?)
# - What is the bounce rate?
# - Location of the visitors/customers
#
# **Client Behavior Analysis Interaction Patterns:**
#
# - How do clients navigate through the old versus the new digital process? Do they follow similar steps or diverge at certain points?
# - Consider another hypothesis. Investigate if there’s a difference in the number of actions (steps) taken by users between the Test and Control groups.
#
# **Power and Effect Size**
# - Calculate the effect size and post-hoc power for the first test: the new design (Test group) had a higher completion rate compared to the old design (Control group), the hypothesis test checked if this difference was statistically significant.
# - Let’s assume we are in the phase of designing the experiment for the same hypothesis test. Do Power Analysis to calculate the minimum sample size for an experiment.
#
# **Streamlit**
#
# - Add Streamlit to your project to achieve Customization and Real-time Analysis.
