# %%
import numpy as np
import pandas as pd

file_path = r"C:\Users\npdan\IH_LABS/Project2/Datasets/Datasets_raw/df_final_web_data_pt_1.csv"
df = pd.read_csv(file_path)
df

#results : 343141 rows × 1 columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 import pandas as pd
#       4 file_path = r"C:\Users\npdan\IH_LABS/Project2/Datasets/Datasets_raw/df_final_web_data_pt_1.csv"
# ----> 5 df = pd.read_csv(file_path)
#       6 df
#
# ...

# %%
print(df.head())
print(df.shape)
# Out:
#   client_id,visitor_id,visit_id,process_step,date_time
# 0  9988021,580560515_7732621733,781255054_2193545...
# 1  9988021,580560515_7732621733,781255054_2193545...
# 2  9988021,580560515_7732621733,781255054_2193545...
# 3  9988021,580560515_7732621733,781255054_2193545...
# 4  9988021,580560515_7732621733,781255054_2193545...
# (343141, 1)

# %%
# Make sure we're working with the first column
df_split = df.iloc[:, 0].str.split(',', expand=True)
df_split.columns = ['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time']

# %%
print(df_split.head())
print(df_split.shape)  # Should be (343141, 5)
# Out:
#   client_id            visitor_id                      visit_id process_step  \
# 0   9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1   9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2   9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3   9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4   9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04
# (343141, 5)

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['client_id,visitor_id,visit_id,process_step,date_time'], dtype='object')
# (343141, 1)

# %%
df = df_split
print(df.columns)
print(df.shape)
# Out:
# Index(['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time'], dtype='object')
# (343141, 5)

# %%
#Save the cleaned file in csv :
df.to_csv('df_final_web_data_pt_1_cleaned.csv', index=False)

# %%
#Check if the cleaning is effective
df.shape
# Out:
# (343141, 5)

# %%
import numpy as np
import pandas as pd

file_path2 = r"C:\Users\npdan\IH_LABS/Project2/Datasets/Datasets_raw/df_final_web_data_pt_2.csv"
df2 = pd.read_csv(file_path2)
df2
# Out:
#        client_id,visitor_id,visit_id,process_step,date_time
# 0       763412,601952081_10457207388,397475557_4044094...
# 1       6019349,442094451_91531546617,154620534_353310...
# 2       6019349,442094451_91531546617,154620534_353310...
# 3       6019349,442094451_91531546617,154620534_353310...
# 4       6019349,442094451_91531546617,154620534_353310...
# ...                                                   ...
# 412259  9668240,388766751_9038881013,922267647_3096648...
# 412260  9668240,388766751_9038881013,922267647_3096648...
# 412261  9668240,388766751_9038881013,922267647_3096648...
# 412262  9668240,388766751_9038881013,922267647_3096648...
# 412263  674799,947159805_81558194550,86152093_47511127...
#
# [412264 rows x 1 columns]

# %%
df2 = df2.iloc[:, 0].str.split(',', expand=True)
df2.columns = ['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time']

# %%
print(df2.columns)
print(df2.shape)
# Out:
# Index(['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time'], dtype='object')
# (412264, 5)

# %%
#Save the cleaned file in csv :
df2.to_csv('df_final_web_data_pt_2_cleaned.csv', index=False)

# %%
#Check if the cleaning is effective
df2.shape
# Out:
# (412264, 5)

# %%
import numpy as np
import pandas as pd

file_path3 = r"C:\Users\npdan\IH_LABS/Project2/Datasets/Datasets_raw/df_final_experiment_clients.csv"
df3 = pd.read_csv(file_path3)
df3
# Out:
#       client_id,Variation
# 0            9988021,Test
# 1            8320017,Test
# 2         4033851,Control
# 3            1982004,Test
# 4         9294070,Control
# ...                   ...
# 70604          2443347,NA
# 70605          8788427,NA
# 70606           266828,NA
# 70607          1266421,NA
# 70608          9895983,NA
#
# [70609 rows x 1 columns]

# %%
df3 = df3.iloc[:, 0].str.split(',', expand=True)
df3.columns = ['client_id', 'Variation']

# %%
print(df3.columns)
print(df3.shape)
# Out:
# Index(['client_id', 'Variation'], dtype='object')
# (70609, 2)

# %%
#Save the cleaned file in csv :
df3.to_csv('df_final_experiment_clients_cleaned.csv', index=False)

# %%
#Check if the cleaning is effective
df3.shape
# Out:
# (70609, 2)

# %%
file_path4 = r"C:\Users\npdan\IH_LABS/Project2/Datasets/Datasets_raw/df_final_demo.csv"
df4 = pd.read_csv(file_path4)
df4
# Out:
#       client_id,clnt_tenure_yr,clnt_tenure_mnth,clnt_age,gendr,num_accts,bal,calls_6_mnth,logons_6_mnth
# 0             836976,6.0,73.0,60.5,U,2.0,45105.3,6.0,9.0
# 1           2304905,7.0,94.0,58.0,U,2.0,110860.3,6.0,9.0
# 2      1439522,5.0,64.0,32.0,U,2.0,52467.78999999999,...
# 3         1562045,16.0,198.0,49.0,M,2.0,67454.65,3.0,6.0
# 4        5126305,12.0,145.0,33.0,F,2.0,103671.75,0.0,3.0
# ...                                                  ...
# 70604     7993686,4.0,56.0,38.5,U,3.0,1411062.68,5.0,5.0
# 70605  8981690,12.0,148.0,31.0,M,2.0,101867.069999999...
# 70606       333913,16.0,198.0,61.5,F,2.0,40745.0,3.0,3.0
# 70607    1573142,21.0,255.0,68.0,M,3.0,475114.69,4.0,4.0
# 70608  5602139,21.0,254.0,59.5,F,3.0,157498.729999999...
#
# [70609 rows x 1 columns]

# %%
df4 = df4.iloc[:, 0].str.split(',', expand=True)
df4.columns = ['client_id', 'clnt_tenure_yr', 'clnt_tenure_mnth', 'clnt_age', 'gendr', 'num_accts', 'bal', 'calls_6_mnth', 'logons_6_mnth']

# %%
print(df4.columns)
print(df4.shape)
# Out:
# Index(['client_id', 'clnt_tenure_yr', 'clnt_tenure_mnth', 'clnt_age', 'gendr',
#        'num_accts', 'bal', 'calls_6_mnth', 'logons_6_mnth'],
#       dtype='object')
# (70609, 9)

# %%
#Save the cleaned file in csv :
df4.to_csv('df_final_demo_cleaned.csv', index=False)

# %%
#Check if the cleaning is effective
df4.shape
# Out:
# (70609, 9)

# %%
df1 = df
df1
# Out:
#        client_id             visitor_id                      visit_id  \
# 0        9988021   580560515_7732621733  781255054_21935453173_531117
# 1        9988021   580560515_7732621733  781255054_21935453173_531117
# 2        9988021   580560515_7732621733  781255054_21935453173_531117
# 3        9988021   580560515_7732621733  781255054_21935453173_531117
# 4        9988021   580560515_7732621733  781255054_21935453173_531117
# ...          ...                    ...                           ...
# 343136   2443347  465784886_73090545671  136329900_10529659391_316129
# 343137   2443347  465784886_73090545671  136329900_10529659391_316129
# 343138   2443347  465784886_73090545671  136329900_10529659391_316129
# 343139   2443347  465784886_73090545671  136329900_10529659391_316129
# 343140   2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# 1            step_2  2017-04-17 15:26:51
# ...

# %%
# Load both CSV files
df1 = pd.read_csv('df_final_web_data_pt_1_cleaned.csv')
df2 = pd.read_csv('df_final_web_data_pt_2_cleaned.csv')

# Merge the dataframes by stacking them (since they have the same columns)
merged_df = pd.concat([df1, df2], ignore_index=True)

# Optional: check the result
print(merged_df.shape)
print(merged_df.head())

# Save the merged dataframe to a new CSV 
merged_df.to_csv('df_final_web_data_combined.csv', index=False)
# Out:
# (755405, 5)
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 1    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 2    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# 3    9988021  580560515_7732621733  781255054_21935453173_531117       step_2
# 4    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
#
#              date_time
# 0  2017-04-17 15:27:07
# 1  2017-04-17 15:26:51
# 2  2017-04-17 15:19:22
# 3  2017-04-17 15:19:13
# 4  2017-04-17 15:18:04

# %%
#Who are the primary clients using this online process?

# Convert 'date_time' to datetime format
df['date_time'] = pd.to_datetime(df['date_time'])

# Filter for rows where process_step is 'start'
df_start = df[df['process_step'].str.lower() == 'start']

# Sort the result by date_time in ascending order
df_sorted = df_start.sort_values(by='date_time', ascending=True)

# Display only client_id and date_time (optional: include more columns if needed)
result = df_sorted[['client_id', 'date_time']]

print(result)
# Out:
#         client_id           date_time
# 35293     7179755 2017-03-15 00:19:28
# 79556     4192640 2017-03-15 00:43:23
# 79552     4192640 2017-03-15 00:44:38
# 104942    6752370 2017-03-15 05:37:35
# 104937    6752370 2017-03-15 05:40:25
# ...           ...                 ...
# 346010    6708979 2017-06-20 23:52:54
# 521478    6187864 2017-06-20 23:56:17
# 519273    4159912 2017-06-20 23:58:40
# 527151    5640210 2017-06-20 23:59:53
# 670704    4227031 2017-06-20 23:59:57
#
# [243945 rows x 2 columns]

# %%
# Save to CSV
result.to_csv('clients_started_process_sorted.csv', index=False)

# %%
#Are the primary clients younger or older, new or long-standing?

# Load the original DataFrames
df_start = pd.read_csv('clients_started_process_sorted.csv')
df_demo = pd.read_csv('df_final_demo_cleaned.csv')

# Merge on 'client_id'
df_merged = pd.merge(df_start, df_demo[['client_id', 'clnt_tenure_mnth', 'clnt_age']], on='client_id', how='left')

# Save the final DataFrame
df_merged.to_csv('clients_started_process_enriched.csv', index=False)

# %%
df_merged.head()
# Out:
#    client_id            date_time  clnt_tenure_mnth  clnt_age
# 0    7179755  2017-03-15 00:19:28             343.0      67.5
# 1    4192640  2017-03-15 00:43:23             174.0      54.0
# 2    4192640  2017-03-15 00:44:38             174.0      54.0
# 3    6752370  2017-03-15 05:37:35             464.0      22.0
# 4    6752370  2017-03-15 05:40:25             464.0      22.0

# %%
# Load the enriched DataFrame
df_enriched = pd.read_csv('clients_started_process_enriched.csv')

# Sort by 'clnt_tenure_mnth' in descending order
df_sorted = df_enriched.sort_values(by='clnt_tenure_mnth', ascending=False)

# Save the sorted DataFrame
df_sorted.to_csv('clients_started_process_enriched_sorted.csv', index=False)

# %%
df_sorted.head()
# Out:
#         client_id            date_time  clnt_tenure_mnth  clnt_age
# 35952      357409  2017-04-05 01:06:00             749.0      51.0
# 193397    4833584  2017-06-05 14:15:29             669.0      45.0
# 64939     3271450  2017-04-11 00:31:48             669.0      48.5
# 107738    7616896  2017-04-28 13:53:35             669.0      78.0
# 107737    7616896  2017-04-28 13:53:35             669.0      78.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Load the sorted enriched data
df = pd.read_csv('clients_started_process_enriched_sorted.csv')

# Set Seaborn style
sns.set(style='whitegrid')

# Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='clnt_age', y='clnt_tenure_mnth', alpha=0.6)

plt.title('Client Tenure (Months) vs Client Age')
plt.xlabel('Client Age')
plt.ylabel('Client Tenure (Months)')
plt.tight_layout()
plt.show()

# %%
# Histogram of clnt_tenure_mnth
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.histplot(df['clnt_tenure_mnth'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Client Tenure (Months)')
plt.xlabel('Tenure (Months)')

# Histogram of clnt_age
plt.subplot(1, 2, 2)
sns.histplot(df['clnt_age'], bins=30, kde=True, color='salmon')
plt.title('Distribution of Client Age')
plt.xlabel('Age')

plt.tight_layout()
plt.show()

# %%
from scipy import stats

# Load the dataset
df = pd.read_csv('clients_started_process_enriched_sorted.csv')

# Select the columns of interest
cols = ['clnt_age', 'clnt_tenure_mnth']

# Calculate statistics
summary_stats = {
    'Mean': df[cols].mean(),
    'Standard Deviation': df[cols].std(),
    'Median': df[cols].median(),
    'Mode': df[cols].mode().iloc[0]  # Take first mode if multiple
}

# Convert to a DataFrame for easy viewing
stats_df = pd.DataFrame(summary_stats)
print(stats_df)
# Out:
#                         Mean  Standard Deviation  Median  Mode
# clnt_age           48.156200           15.761511    50.0  57.0
# clnt_tenure_mnth  154.075906           83.689111   142.0  58.0

# %%
# Load the dataset
df0 = pd.read_csv('df_final_demo_cleaned.csv')

# Select the columns of interest
cols = ['clnt_age', 'clnt_tenure_mnth']

# Calculate statistics
summary_stats = {
    'Mean': df0[cols].mean(),
    'Standard Deviation': df0[cols].std(),
    'Median': df0[cols].median(),
    'Mode': df0[cols].mode().iloc[0]  # Take first mode if multiple
}

# Convert to a DataFrame for easy viewing
stats_df0 = pd.DataFrame(summary_stats)
print(stats_df0)
# Out:
#                         Mean  Standard Deviation  Median  Mode
# clnt_age           46.442240           15.591273    47.0  58.5
# clnt_tenure_mnth  150.659367           82.089854   136.0  58.0
